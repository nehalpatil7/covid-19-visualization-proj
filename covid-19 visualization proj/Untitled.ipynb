# %%
import pandas as pd

from pyecharts.charts import Map,Geo
from pyecharts import options as opts, render
from pyecharts.globals import ThemeType

# %%
dataset=pd.read_csv("covid-data.csv")

# %%
dataset['date']=pd.to_datetime(dataset['date'])
df = dataset.sort_values(by=['date'], ascending=False) #sort data by date
map_df=df[df['date']=='2020-07-03']
map_df.reset_index(drop=True, inplace=True)
map_df
# Out:
#     iso_code      continent    location       date  total_cases  new_cases  \
# 0        BEL         Europe     Belgium 2020-07-03      61727.0      129.0
# 1        BDI         Africa     Burundi 2020-07-03        191.0       21.0
# 2        AZE           Asia  Azerbaijan 2020-07-03      19267.0      583.0
# 3        COM         Africa     Comoros 2020-07-03        309.0        6.0
# 4        HND  North America    Honduras 2020-07-03      22116.0      996.0
# ..       ...            ...         ...        ...          ...        ...
# 182      TCD         Africa        Chad 2020-07-03        871.0        3.0
# 183      SYR           Asia       Syria 2020-07-03        328.0       16.0
# 184      RUS         Europe      Russia 2020-07-03     666941.0     6710.0
# 185      ETH         Africa    Ethiopia 2020-07-03       5846.0        0.0
# 186      BGD           Asia  Bangladesh 2020-07-03     156391.0     3114.0
#
#      new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                88.714        9765.0         4.0                4.857  ...
# 1                 6.714           1.0         0.0                0.000  ...
# 2               556.857         235.0         7.0                6.857  ...
# 3                 5.286           7.0         0.0                0.000  ...
# 4               874.571         605.0        14.0               19.143  ...
# ..                  ...           ...         ...                  ...  ...
# 182               0.857          74.0         0.0                0.000  ...
# 183              10.429          10.0         1.0                0.286  ...
# 184            6715.000        9844.0       176.0              153.429  ...
# 185              60.143         103.0         0.0                2.000  ...
# 186            3702.429        1968.0        42.0               43.857  ...
#
#      gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0         42658.576              0.2                114.898
# 1           702.225             71.7                293.068
# 2         15847.419              NaN                559.812
# 3          1413.890             18.1                261.516
# 4          4541.795             16.0                240.208
# ..              ...              ...                    ...
# 182        1768.153             38.4                280.995
# 183             NaN              NaN                376.264
# 184       24765.954              0.1                431.297
# 185        1729.927             26.7                182.634
# 186        3523.984             14.8                298.003
#
#      diabetes_prevalence  female_smokers  male_smokers  \
# 0                   4.29            25.1          31.4
# 1                   6.05             NaN           NaN
# 2                   7.11             0.3          42.5
# 3                  11.88             4.4          23.6
# 4                   7.21             2.0           NaN
# ..                   ...             ...           ...
# 182                 6.10             NaN           NaN
# 183                  NaN             NaN           NaN
# 184                 6.18            23.4          58.3
# 185                 7.47             0.4           8.5
# 186                 8.38             1.0          44.7
#
#      handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                       NaN                        5.64            81.63
# 1                     6.144                        0.80            61.58
# 2                    83.241                        4.70            73.00
# 3                    15.574                        2.20            64.32
# 4                    84.169                        0.70            75.27
# ..                      ...                         ...              ...
# 182                   5.818                         NaN            54.24
# 183                  70.598                        1.50            72.70
# 184                     NaN                        8.05            72.58
# 185                   7.960                        0.30            66.60
# 186                  34.808                        0.80            72.59
#
#      human_development_index
# 0                      0.916
# 1                      0.417
# 2                      0.757
# 3                      0.503
# 4                      0.617
# ..                       ...
# 182                    0.404
# 183                    0.536
# 184                    0.816
# 185                    0.463
# 186                    0.608
#
# [187 rows x 52 columns]

# %%
country=list(map_df['location'])
totalcases=list(map_df['total_cases'])

# %%
list1 = [[country[i],totalcases[i]] for i in range(len(country))]
map_1 = Map(init_opts=opts.InitOpts(width="1000px", height="460px",theme=ThemeType.ROMANTIC))
map_1.add('Total Confirmed Cases', list1,maptype='world',is_map_symbol_show=False)
map_1.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
map_1.set_global_opts(visualmap_opts=opts.VisualMapOpts(max_=1100000,is_piecewise=True,pieces=[
 {"min": 500000},
 {"min": 200000, "max": 499999},
 {"min": 100000, "max": 199999},
 {"min": 50000, "max": 99999},
 {"min": 10000, "max": 49999},
 {"max": 9999},]),
 title_opts=opts.TitleOpts(title="Covid-19 Worldwide Total Cases",
 subtitle='Till July 03rd,2020',pos_left='center',padding=0,item_gap=2,
 title_textstyle_opts= opts.TextStyleOpts(color='darkblue',
 font_weight='bold',font_family='Courier New',
 font_size=30),subtitle_textstyle_opts= opts.TextStyleOpts(color='grey',
 font_weight='bold',font_family='Courier New',
 font_size=13)),legend_opts=opts.LegendOpts(is_show=False))
map_1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world', 'romantic':'https://assets.pyecharts.org/assets/themes/romantic'
#         }
#     });
# </script>
#
#         <div id="302bff3748c44516ad862e1f15c7070d" style="width:1000px; height:460px;"></div>
#
# <script>
#         require(['echarts', 'world', 'romantic'], function(echarts) {
#                 var chart_302bff3748c44516ad862e1f15c7070d = echarts.init(
#                     document.getElementById('302bff3748c44516ad862e1f15c7070d'), 'romantic', {renderer: 'canvas'});
#                 var option_302bff3748c44516ad862e1f15c7070d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "map",
#             "name": "Total Confirmed Cases",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "Belgium",
#                     "value": 61727.0
#                 },
#                 {
#                     "name": "Burundi",
#                     "value": 191.0
#                 },
#                 {
#                     "name": "Azerbaijan",
#                     "value": 19267.0
#                 },
#                 {
#                     "name": "Comoros",
#                     "value": 309.0
#                 },
#                 {
#                     "name": "Honduras",
#                     "value": 22116.0
#                 },
#                 {
#                     "name": "Argentina",
#                     "value": 72786.0
#                 },
#                 {
#                     "name": "Namibia",
#                     "value": 350.0
#                 },
#                 {
#                     "name": "Montenegro",
#                     "value": 663.0
#                 },
#                 {
#                     "name": "Gabon",
#                     "value": 5620.0
#                 },
#                 {
#                     "name": "Tunisia",
#                     "value": 1181.0
#                 },
#                 {
#                     "name": "Estonia",
#                     "value": 1991.0
#                 },
#                 {
#                     "name": "Cambodia",
#                     "value": 141.0
#                 },
#                 {
#                     "name": "Nicaragua",
#                     "value": 2519.0
#                 },
#                 {
#                     "name": "Peru",
#                     "value": 295599.0
#                 },
#                 {
#                     "name": "Yemen",
#                     "value": 1240.0
#                 },
#                 {
#                     "name": "Liberia",
#                     "value": 833.0
#                 },
#                 {
#                     "name": "Belarus",
#                     "value": 62997.0
#                 },
#                 {
#                     "name": "Democratic Republic of Congo",
#                     "value": 7311.0
#                 },
#                 {
#                     "name": "Turkey",
#                     "value": 203456.0
#                 },
#                 {
#                     "name": "China",
#                     "value": 84838.0
#                 },
#                 {
#                     "name": "Chile",
#                     "value": 288089.0
#                 },
#                 {
#                     "name": "Vatican",
#                     "value": 12.0
#                 },
#                 {
#                     "name": "Japan",
#                     "value": 19185.0
#                 },
#                 {
#                     "name": "Czechia",
#                     "value": 12319.0
#                 },
#                 {
#                     "name": "Malaysia",
#                     "value": 8648.0
#                 },
#                 {
#                     "name": "Moldova",
#                     "value": 17445.0
#                 },
#                 {
#                     "name": "Lesotho",
#                     "value": 35.0
#                 },
#                 {
#                     "name": "Saint Kitts and Nevis",
#                     "value": 15.0
#                 },
#                 {
#                     "name": "Dominican Republic",
#                     "value": 35148.0
#                 },
#                 {
#                     "name": "Haiti",
#                     "value": 6230.0
#                 },
#                 {
#                     "name": "Afghanistan",
#                     "value": 32314.0
#                 },
#                 {
#                     "name": "Sudan",
#                     "value": 9663.0
#                 },
#                 {
#                     "name": "Italy",
#                     "value": 241184.0
#                 },
#                 {
#                     "name": "Slovakia",
#                     "value": 1720.0
#                 },
#                 {
#                     "name": "Seychelles",
#                     "value": 81.0
#                 },
#                 {
#                     "name": "Cape Verde",
#                     "value": 1382.0
#                 },
#                 {
#                     "name": "Ghana",
#                     "value": 19388.0
#                 },
#                 {
#                     "name": "Qatar",
#                     "value": 98653.0
#                 },
#                 {
#                     "name": "Somalia",
#                     "value": 2944.0
#                 },
#                 {
#                     "name": "Tanzania",
#                     "value": 509.0
#                 },
#                 {
#                     "name": "Tajikistan",
#                     "value": 6058.0
#                 },
#                 {
#                     "name": "Botswana",
#                     "value": 277.0
#                 },
#                 {
#                     "name": "Israel",
#                     "value": 28495.0
#                 },
#                 {
#                     "name": "South Korea",
#                     "value": 13030.0
#                 },
#                 {
#                     "name": "Barbados",
#                     "value": 97.0
#                 },
#                 {
#                     "name": "Congo",
#                     "value": 1557.0
#                 },
#                 {
#                     "name": "Uganda",
#                     "value": 911.0
#                 },
#                 {
#                     "name": "Malta",
#                     "value": 672.0
#                 },
#                 {
#                     "name": "Saint Vincent and the Grenadines",
#                     "value": 29.0
#                 },
#                 {
#                     "name": "Palestine",
#                     "value": 3334.0
#                 },
#                 {
#                     "name": "Armenia",
#                     "value": 27320.0
#                 },
#                 {
#                     "name": "Guyana",
#                     "value": 256.0
#                 },
#                 {
#                     "name": "Lebanon",
#                     "value": 1830.0
#                 },
#                 {
#                     "name": "Andorra",
#                     "value": 855.0
#                 },
#                 {
#                     "name": "Ecuador",
#                     "value": 60657.0
#                 },
#                 {
#                     "name": "Eswatini",
#                     "value": 909.0
#                 },
#                 {
#                     "name": "Antigua and Barbuda",
#                     "value": 68.0
#                 },
#                 {
#                     "name": "Niger",
#                     "value": 1082.0
#                 },
#                 {
#                     "name": "Poland",
#                     "value": 35405.0
#                 },
#                 {
#                     "name": "Costa Rica",
